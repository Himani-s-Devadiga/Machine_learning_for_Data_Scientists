# %% [markdown]
# # Understanding Your Data

# %% [markdown]
# ### "Understanding the data comes before analysis"

# %%
# Load a dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
  "Student":["A","B","C","D","E","F","G","H"],
  "Age":[20,21,20,22,21,20,23,21],
  "Gender":["F","M","F","M","F","M","F","F"],
  "Study_Hours":[5,2,7,4,6,3,8,5],
  "Marks":[78,55,88,65,82,60,92,75],
  "Passed":["Yes","No","Yes","Yes","Yes","No","Yes","Yes"]
}

df=pd.DataFrame(data)
df
# Out:
#   Student  Age Gender  Study_Hours  Marks Passed
# 0       A   20      F            5     78    Yes
# 1       B   21      M            2     55     No
# 2       C   20      F            7     88    Yes
# 3       D   22      M            4     65    Yes
# 4       E   21      F            6     82    Yes
# 5       F   20      M            3     60     No
# 6       G   23      F            8     92    Yes
# 7       H   21      F            5     75    Yes

# %%
df.head()
# Out:
#   Student  Age Gender  Study_Hours  Marks Passed
# 0       A   20      F            5     78    Yes
# 1       B   21      M            2     55     No
# 2       C   20      F            7     88    Yes
# 3       D   22      M            4     65    Yes
# 4       E   21      F            6     82    Yes

# %%
df.tail()
# Out:
#   Student  Age Gender  Study_Hours  Marks Passed
# 3       D   22      M            4     65    Yes
# 4       E   21      F            6     82    Yes
# 5       F   20      M            3     60     No
# 6       G   23      F            8     92    Yes
# 7       H   21      F            5     75    Yes

# %%
df.shape
# Out:
# (8, 6)

# %%
# no.of columns to show in shape
df.shape[1]
# Out:
# 6

# %%
df.columns
# Out:
# Index(['Student', 'Age', 'Gender', 'Study_Hours', 'Marks', 'Passed'], dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Student', 'Age', 'Gender', 'Study_Hours', 'Marks', 'Passed']

# %%
df.dtypes
# Out:
# Student        object
# Age             int64
# Gender         object
# Study_Hours     int64
# Marks           int64
# Passed         object
# dtype: object

# %%
# info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Student      8 non-null      object
#  1   Age          8 non-null      int64
#  2   Gender       8 non-null      object
#  3   Study_Hours  8 non-null      int64
#  4   Marks        8 non-null      int64
#  5   Passed       8 non-null      object
# dtypes: int64(3), object(3)
# memory usage: 516.0+ bytes

# %%
# Missing values
df.isnull()
# Out:
#    Student    Age  Gender  Study_Hours  Marks  Passed
# 0    False  False   False        False  False   False
# 1    False  False   False        False  False   False
# 2    False  False   False        False  False   False
# 3    False  False   False        False  False   False
# 4    False  False   False        False  False   False
# 5    False  False   False        False  False   False
# 6    False  False   False        False  False   False
# 7    False  False   False        False  False   False

# %%
df.isnull().sum()
# Out:
# Student        0
# Age            0
# Gender         0
# Study_Hours    0
# Marks          0
# Passed         0
# dtype: int64

# %%
# Percentage of missing values
missing_percentage=df.isnull().mean()*100
missing_percentage
# Out:
# Student        0.0
# Age            0.0
# Gender         0.0
# Study_Hours    0.0
# Marks          0.0
# Passed         0.0
# dtype: float64

# %%
# Duplicate rows
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Remove duplicates
df=df.drop_duplicates()
df
# Out:
#   Student  Age Gender  Study_Hours  Marks Passed
# 0       A   20      F            5     78    Yes
# 1       B   21      M            2     55     No
# 2       C   20      F            7     88    Yes
# 3       D   22      M            4     65    Yes
# 4       E   21      F            6     82    Yes
# 5       F   20      M            3     60     No
# 6       G   23      F            8     92    Yes
# 7       H   21      F            5     75    Yes

# %%
# Numerical summary
df.describe()
# Out:
#              Age  Study_Hours      Marks
# count   8.000000         8.00   8.000000
# mean   21.000000         5.00  74.375000
# std     1.069045         2.00  13.298093
# min    20.000000         2.00  55.000000
# 25%    20.000000         3.75  63.750000
# 50%    21.000000         5.00  76.500000
# 75%    21.250000         6.25  83.500000
# max    23.000000         8.00  92.000000

# %%
# Categorical summary
df["Gender"].describe()
# Out:
# count     8
# unique    2
# top       F
# freq      5
# Name: Gender, dtype: object

# %%
# Unique values
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df["Gender"].nunique()
# Out:
# 2

# %%
# Value counts
df['Gender'].value_counts()
# Out:
# Gender
# F    5
# M    3
# Name: count, dtype: int64

# %%
# Value count percentage
df["Gender"].value_counts(normalize=True) * 100
# Out:
# Gender
# F    62.5
# M    37.5
# Name: proportion, dtype: float64

# %%
# Checking suspicious values

## This is where real data cleaning begins.
df["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
# Checking numerical ranges
df["Age"].describe()
# Out:
# count     8.000000
# mean     21.000000
# std       1.069045
# min      20.000000
# 25%      20.000000
# 50%      21.000000
# 75%      21.250000
# max      23.000000
# Name: Age, dtype: float64

# %%
# nunique() for every column
df.nunique()
# Out:
# Student        8
# Age            4
# Gender         2
# Study_Hours    7
# Marks          8
# Passed         2
# dtype: int64

# %% [markdown]
# ## Key Findings:
#
# 1. The dataset contains 8 rows and 6 columns.
#
# 2. The numerical columns are 3.
#
# 3. The categorical columns are 2.
#
# 4. The dataset contains 0 missing values.
#
# 5. The dataset contains 0 duplicate rows.
#
# 6. The average marks are 74.375.
#
# 7. The median marks are 76.5.
#
# 8. The minimum marks are 55 and the maximum marks are 92.
#
# 9. There are 2 unique Gender categories.
#
# 10. The most frequent Gender category is Female(F).
#
# 11. One potential data-quality issue I noticed is -
# (1)- the passing threshold is not specified, so we cannot verify whether the Passed values are correctly assigned..
# (2)-No information about the units/context of Study_Hours
# Are these hours per day, per week, or total study hours? The column name alone doesn't tell us.
# (3)-No information about the units/context of Study_Hours
# Are these hours per day, per week, or total study hours? The column name alone doesn't tell us.
#
# 12. Before performing EDA, I should first understand the data.
